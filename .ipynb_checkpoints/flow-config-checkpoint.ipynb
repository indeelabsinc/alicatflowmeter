# %% [markdown]
# # Alicat Scientific Flowmeter Code to Read & Plot Data #
# ### Code last updated: July 12, 2018 ###

# %% [markdown]
# This code interfaces with the Alicat Scientific Flowmeter to read and plot data

# %%
import matplotlib.pyplot as plt
import alicat
import numpy as np
from time import time

# set port for flow meter
flow_meter = alicat.FlowMeter(port=" /dev/tty.usbserial-FT1QWVBE")

# close then open serial connection
flow_meter.connection.close()
flow_meter.connection.open()

# set gas type
flow_meter.set_gas('N2')

# set approximate run time
runtime = 30  # seconds

# Fill in data as it comes in from the controller
n = 0
t0, t = time(), 0

times, flows = [], []

while (t < runtime):
   # try:
    status = flow_meter.get()
    flows.append(status['volumetric_flow'])
    times.append(t)
    t = time() - t0
    #time.sleep(0.5)

flow_meter.connection.close()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/serial/serialposix.py in open(self)
#     264         try:
# --> 265             self.fd = os.open(self.portstr, os.O_RDWR | os.O_NOCTTY | os.O_NONBLOCK)
#     266         except OSError as msg:
#
# FileNotFoundError: [Errno 2] No such file or directory: '/dev/tty.usbserial-FT1QXE0L'
#
# During handling of the above exception, another exception occurred:
#
# SerialException                           Traceback (most recent call last)
# <ipython-input-7-3cfc2a28fec8> in <module>()
#       9 # close then open serial connection
#      10 flow_meter.connection.close()
# ---> 11 flow_meter.connection.open()
#      12
#      13 # set gas type
#
# ~/anaconda3/lib/python3.6/site-packages/serial/serialposix.py in open(self)
#     266         except OSError as msg:
#     267             self.fd = None
# --> 268             raise SerialException(msg.errno, "could not open port {}: {}".format(self._port, msg))
#     269         #~ fcntl.fcntl(self.fd, fcntl.F_SETFL, 0)  # set blocking
#     270
#
# SerialException: [Errno 2] could not open port /dev/tty.usbserial-FT1QXE0L: [Errno 2] No such file or directory: '/dev/tty.usbserial-FT1QXE0L'

# %% [markdown]
# ## Plot Flow data vs. Time ##

# %%
import pandas as pd

flowdata = pd.DataFrame({'Times_(s)': times,'Flow_Rate_(mLpm)': flows})


#flowdata[['Times_(s)','Flow_Rate_(mLpm)']].plot()
flowdata.plot(x='Times_(s)', y='Flow_Rate_(mLpm)', marker='*')

# %% [markdown]
# ## Get Dataset Statistics ##

# %%
flowdata.describe()
# Out:
#        Flow_Rate_(mLpm)   Times_(s)
# count        300.000000  300.000000
# mean          -2.443333    5.000422
# std            0.497609    2.892100
# min           -3.000000    0.000000
# 25%           -3.000000    2.503149
# 50%           -2.000000    5.005406
# 75%           -2.000000    7.492849
# max           -2.000000    9.980070

# %% [markdown]
# ## Export as a csv for data collection ##

# %%
flowdata.to_csv('flowdata_exp_1_0V_0Hz_140PSI_180712', sep=',')
